# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\children anemia.csv")

# %%
data
# Out:
#       Age in 5-year groups Type of place of residence  \
# 0                    40-44                      Urban
# 1                    35-39                      Urban
# 2                    25-29                      Urban
# 3                    25-29                      Urban
# 4                    20-24                      Urban
# ...                    ...                        ...
# 33919                35-39                      Rural
# 33920                25-29                      Rural
# 33921                25-29                      Rural
# 33922                20-24                      Rural
# 33923                40-44                      Rural
#
#       Highest educational level Wealth index combined  \
# 0                        Higher               Richest
# 1                        Higher               Richest
# 2                        Higher               Richest
# 3                     Secondary               Richest
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()
data = data.apply(le.fit_transform)

# %%
data
# Out:
#        Age in 5-year groups  Type of place of residence  \
# 0                         5                           1
# 1                         4                           1
# 2                         2                           1
# 3                         2                           1
# 4                         1                           1
# ...                     ...                         ...
# 33919                     4                           0
# 33920                     2                           0
# 33921                     2                           0
# 33922                     1                           0
# 33923                     5                           0
#
#        Highest educational level  Wealth index combined  \
# 0                              0                      4
# 1                              0                      4
# 2                              0                      4
# 3                              3                      4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33924 entries, 0 to 33923
# Data columns (total 17 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Age in 5-year groups                                                   33924 non-null  int32
#  1   Type of place of residence                                             33924 non-null  int32
#  2   Highest educational level                                              33924 non-null  int32
#  3   Wealth index combined                                                  33924 non-null  int32
#  4   Births in last five years                                              33924 non-null  int64
#  5   Age of respondent at 1st birth                                         33924 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# Age in 5-year groups                                                     0
# Type of place of residence                                               0
# Highest educational level                                                0
# Wealth index combined                                                    0
# Births in last five years                                                0
# Age of respondent at 1st birth                                           0
# Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)    0
# Anemia level                                                             0
# Have mosquito bed net for sleeping (from household questionnaire)        0
# Smokes cigarettes                                                        0
# Current marital status                                                   0
# Currently residing with husband/partner                                  0
# ...

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#        Age in 5-year groups  Type of place of residence  \
# 0                         5                           1
# 1                         4                           1
# 2                         2                           1
# 3                         2                           1
# 4                         1                           1
# ...                     ...                         ...
# 33919                     4                           0
# 33920                     2                           0
# 33921                     2                           0
# 33922                     1                           0
# 33923                     5                           0
#
#        Highest educational level  Wealth index combined  \
# 0                              0                      4
# 1                              0                      4
# 2                              0                      4
# 3                              3                      4
# ...

# %%
data.describe()
# Out:
#        Age in 5-year groups  Type of place of residence  \
# count          29246.000000                29246.000000
# mean               2.637455                    0.366990
# std                1.420907                    0.481992
# min                0.000000                    0.000000
# 25%                2.000000                    0.000000
# 50%                3.000000                    0.000000
# 75%                4.000000                    1.000000
# max                6.000000                    1.000000
#
#        Highest educational level  Wealth index combined  \
# count               29246.000000           29246.000000
# mean                    1.751453               1.832422
# std                     1.009551               1.365722
# min                     0.000000               0.000000
# 25%                     1.000000               1.000000
# 50%                     2.000000               2.000000
# 75%                     3.000000               3.000000
# ...

# %%
data.corr()
# Out:
#                                                     Age in 5-year groups  \
# Age in 5-year groups                                            1.000000
# Type of place of residence                                      0.063318
# Highest educational level                                      -0.120982
# Wealth index combined                                           0.065041
# Births in last five years                                      -0.049595
# Age of respondent at 1st birth                                  0.321090
# Hemoglobin level adjusted for altitude and smok...              0.008770
# Anemia level                                                    0.006899
# Have mosquito bed net for sleeping (from househ...             -0.024219
# Smokes cigarettes                                              -0.006263
# Current marital status                                          0.046912
# Currently residing with husband/partner                        -0.071965
# ...

# %%
plt.figure(figsize = (24,12))
sn.heatmap(data.corr() , annot = True)
# Out:
# <Axes: >

# %%
sn.distplot(data['Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)'] , color = 'red')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_30360\1717781902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)'] , color = 'red')
# <Axes: xlabel='Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)', ylabel='Density'>

# %%
sn.distplot(data['Age in 5-year groups'] , color = 'red')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_30360\3609764063.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Age in 5-year groups'] , color = 'red')
# <Axes: xlabel='Age in 5-year groups', ylabel='Density'>

# %%
sn.boxplot(data['Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)'] )
# Out:
# <Axes: >

# %%
sn.scatterplot(x = 'Age of respondent at 1st birth' , y = 'Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)' , data = data , color = 'red')
# Out:
# <Axes: xlabel='Age of respondent at 1st birth', ylabel='Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)'>

# %%
stats.probplot(data['Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)'] , plot = plt)
# Out:
# ((array([-4.06808742, -3.85642573, -3.74079157, ...,  3.74079157,
#           3.85642573,  4.06808742]),
#   array([  0,   0,   0, ..., 123, 123, 123], dtype=int64)),
#  (25.124690409061397, 99.1581412842782, 0.8776185619415613))

# %%
stats.probplot(data["Age of respondent at 1st birth"] , plot = plt)
# Out:
# ((array([-4.06808742, -3.85642573, -3.74079157, ...,  3.74079157,
#           3.85642573,  4.06808742]),
#   array([ 0,  0,  0, ..., 32, 32, 33], dtype=int64)),
#  (4.280328849994491, 7.773199753812488, 0.9667214735707355))
